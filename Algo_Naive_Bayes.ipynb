# %% [markdown]
# # Naive Bayes

# %% [markdown]
# Bayes theoram given by Thomas Bayes and this theoram is basis for Naive Bayes Algorithm. Based on conditional probability given by Naive Bayes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bayes Theoram

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Terminology

# %% [markdown]
# #### Posterior Probability, Likelihood, Class Prior Probability, Predictor Probability

# %% [markdown]
# - Bayes theoram provides us with updated probability of an event (posterior probability) given new information.
# -  We call it updated probability because we r taking class prior probability in the formula and then calculating posterior probability (probability of class given some evidence)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Application

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Naive Bayes is primarily used for **text classification**, which involves high dimensional training datasets. Some eg's include spam filteration, sentimental analysis, and classifying news articles.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Interpreting Bayes theoram with Single Predictor

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Interpreting Bayes theoram with Multiple Predictors

# %% [markdown]
# ### Probability of independent events

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Probability of dependent events

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Example - Here here we have P(Outlook=Sunny **and** Humidity=High) which can be formulated as P(Outlook=Sunny) * P(Humidity=High). This holds provided features r independent/naive.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Apply Naive Bayes on Weather Dataset

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Frequency Table and Likelihood table

# %% [markdown]
# - Frequency Table will give P(c), P(x) and Likelihood table gives P(x|c)
# - P(c|x) is posterior/updated probability.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Using Frequency Table and Likelihood table we substitute values in Bayes theoram equation. Since here we r comparing 2 equations so in this case only we can ignore denominators.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We need to normalize these probabilities as these are equivalent probabilities because we have removed the denominator term. If after normalization the probbailities add to 1 also means that your answer is correct.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here 0.205 (Probbaility of yes) and 0.795 (Probability of no) add to 1 as expected.

# %% [markdown]
# ## Types of Naive Bayes Classifier

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Discrete data is quantitative that can be measured with numbers while Categorical data is qualitative (non-numerical). Discrete data like number of items, categorical like categories yes and no.

# %% [markdown]
# ## Summary

# %% [markdown]
# ![image.png](attachment:image.png)
