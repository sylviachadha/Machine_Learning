# %% [markdown]
# # Classification Metrics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Accuracy, Precision, Sensitivity, Specificity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$NOTE$$

# %% [markdown]
# ### *Denominator as well as Numerator both are referring to predictions i.e. ouputs received from model in below 2 formula's*

# %% [markdown]
# ### <font color=blue>1. Precision (Positive Predictive Value) and 2. Negative Predictive Value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  Precision or (Positive Predictive Value)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Negative Predictive Value

# %% [markdown]
# Among all the Negative Predictions, how many were predicted correctly.

# %% [markdown]
# $$NOTE$$

# %% [markdown]
# ### *Denominator is referring to actual/true values and numerator is referring to predicted values in all 4 formula's below - TPR, TNR, FPR, FNR*

# %% [markdown]
# ### <font color=green>1. (True Positive Rate)/Sensitivity/Recall  and  2. (True Negative Rate)/Specificity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$TPR$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$TNR$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <font color=orange> 3. (False Positive Rate) and  4. (False Negative Rate)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$FPR$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$FNR$$

# %% [markdown]
# Out of all Positive classes how many instances were predicted incorrectly.

# %% [markdown]
# ### Hence we conclude for above 6 formula's (marked in blue, green,orange) as -
#
# - *PPV and NPV are predictions(numerator) w.r.t model itself(denominator)*
#
#
# - *TPR and TNR are predictions(numerator) w.r.t actual values(denomiantor)*
#
#
# - *FPR and FNR are predictions(numerator) w.r.t actual values(denomiantor)*

# %% [markdown]
# ## F1 Score

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ROC Curve and ROC-AUC

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### <font color = magenta>TPR vs FPR/False alarm for various threshold values
#
# By default predictions are based on threshold of 0.5.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color = magenta>Ideally, we would want to maximize the TPR and minimize the FPR.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Whether you want to minimize False Negative or minimize False Positive based on the problem statement -

# %% [markdown]
# ### Scenarios - Disease Prediction vs Biometric Access

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Class Imbalance Problem in Binary Classification

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Summary

# %% [markdown]
# ![image.png](attachment:image.png)
