# %% [markdown]
# ## ML Libraries

# %% [markdown]
# ## 1. Scikit Learn

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Its a De Facto Library for ML & provides a wide range of algorithms for supervised and unsupervised learning.
# - It offers a vast array of functions & modules for modelling the data.

# %% [markdown]
# ## Modules in Scikit Learn

# %% [markdown]
# Scikit learn provides methods to split the dataset, perform pre-processing activities as well as provides algorithms for machine learning tasks of classification, regression and clustering etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Split Dataset using train_test split function
# - Perform pre-processing using functions like Standard_scalar
# - ML tasks like Classification, Regression or Clustering using methods from scikit learn as below-

# %% [markdown]
# ![Xnip2022-08-06_13-01-25.jpg](attachment:Xnip2022-08-06_13-01-25.jpg)

# %% [markdown]
# ## Inbuilt datasets in Scikit Learn
#
# These inbuilt datasets can be loaded into python dictionary objects.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Xnip2022-08-06_13-04-04.jpg](attachment:Xnip2022-08-06_13-04-04.jpg)
